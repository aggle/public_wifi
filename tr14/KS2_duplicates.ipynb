# %% [markdown]
# # Finding duplicate stars
# Filename: KS2_dubplicates.ipynb
#
# This notebook is dedicated to identifying duplicate detections in the KS2 database. A duplicate detection is defined as one where different names ("NMAST" values) are used to define the same object, either in the same exposure, or in different exposures.
#
# An object is identified by its flux and position. The position can either be in the individual exposure, or in the master frame.

# %%
from astropy.io import fits
import pandas as pd

# %%
from pathlib import Path

# %%
from importlib import reload
from utils import ks2_utils, shared_utils, image_utils

# %%
import re
import numpy as np

# %% [markdown]
# # INPUT.KS2

# %%
ks2_filtermapper = ks2_utils.get_filter_mapper()

# %%
ks2_filemapper = ks2_utils.get_file_mapper()

# %% [markdown]
# # LOGR.XYVIQ1
#
# LOGR.XYVIQ1 gives the average position for each source on the master frame (cols 1 and 2), the average flux (cols 5 and 11), the flux sigma (cols 6 and 12), and fit quality (cols 7 and 13) in each filter)

# %%
reload(ks2_utils)
master_catalog_df = ks2_utils.get_master_catalog(raw=True)

# %%
master_catalog_df.head()
# Out:
#    umast0  vmast0  mmast1     NMAST   zmast1  szmast1     q1    o1  f1  g1  \
# 0  736.37   91.51 -2.3045  R0000001    8.352    2.586  0.900  0.01   9   9
# 1  737.04   34.36 -3.2771  R0000002   20.458    2.260  0.899  0.00   9   9
# 2  740.65   61.26 -5.9669  R0000003  243.655    3.332  0.999  0.01   9   9
# 3  745.91   93.19 -2.9646  R0000004   15.340    1.092  0.968  0.01   9   9
# 4  749.93  124.75 -4.4803  R0000005   61.959    3.305  0.997  0.00   9   9
#
#     zmast2  szmast2     q2    o2  f2  g2
# 0   14.088    1.538  0.963  0.01   9   9
# 1    9.987    2.508  0.909  0.00  16  16
# 2  177.850    2.386  0.999  0.02   9   9
# 3   19.786    2.601  0.982  0.01   9   9
# 4   84.200    2.850  0.998  0.00  18  18

# %% [markdown]
# # LOGR.FIND_NIMFO

# %%
reload(ks2_utils)
point_sources_df = ks2_utils.get_point_source_catalog(raw=True)
# Out:
# /Users/jaguilar/miniconda3/envs/astro37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (20,28,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
point_sources_df.head(5)
# Out:
#      umast   vmast    magu  utile  vtile    z0  sz0  f0  g0      u1  ...   o3  \
# 0  736.424  91.482 -2.0238    0.0    0.0   6.5  0.8   0   1  31.849  ...  0.0
# 1  736.459  91.452 -1.4531    0.0    0.0   3.7  0.8   0   1  31.918  ...  0.0
# 2  736.323  91.491 -2.5450    0.0    0.0  10.4  0.8   0   1  31.646  ...  0.0
# 3  736.306  91.445 -2.2584    0.0    0.0   8.3  0.8   0   1  31.611  ...  0.0
# 4  736.398  91.671 -2.5036    0.0    0.0   9.6  0.8   0   1  31.797  ...  0.0
#
#    f3  g3     NMAST  ps_tile_id  tile_id  master_exp_id  filt_id  unk  chip_id
# 0   1   1  R0000001        L005     N001           G004       F1    C        1
# 1   1   1  R0000001        L005     N002           G006       F1    C        1
# 2   1   1  R0000001        L005     N003           G007       F1    C        1
# 3   1   1  R0000001        L005     N004           G009       F1    C        1
# 4   1   1  R0000001        L005     N005           G010       F1    C        1
#
# [5 rows x 42 columns]

# %% [markdown]
# # Generate distance matrix

# %%
exp_gb = point_sources_df.groupby("master_exp_id")
exp_df = exp_gb.get_group(list(exp_gb.groups)[0])

# %%
reload(ks2_utils)
dist_mat = ks2_utils.generate_exposure_distance_matrix(exp_df, same_nan=True)

# %%
# make a list of all the sources that have dist = 0
np.tril(dist_mat, k=0)[:4,:4]
# Out:
# array([[         nan,   0.        ,   0.        ,   0.        ],
#        [ 43.62931268,          nan,   0.        ,   0.        ],
#        [ 33.27131873,  10.37003013,          nan,   0.        ],
#        [156.18065565, 112.56791428, 122.93750628,          nan]])

# %%
tril_ind = np.tril_indices_from(dist_mat, k=-1)
dist_mat.values[tril_ind[0], tril_ind[1]]
# Out:
# array([43.62931268, 33.27131873, 10.37003013, ..., 21.44514222,
#        16.92549925, 24.70643641])

# %%
# neighbors = dist_mat[(dist_mat[row['NMAST']] < 100) & (dist_mat[row['NMAST']] > 0) ][row['NMAST']]
# neighbors.index

# %%
samesies = []
for i, row in dist_mat.iterrows():
    tmp = row[row == 0]
    if len(tmp) > 0:
#         print(tmp.name, tmp.keys().values)
        samesies.append(set([tmp.name] + list(tmp.keys().values)))

# %%
# make a set out of each key, pair
samesies[0]
# Out:
# {'R0001452', 'R0001454'}

# %%
# fig, ax = plt.subplots(1, 1)

# hist_args = {'histtype':'step'}
# tril_ind = np.tril_indices(dist_mat.shape[0])
# hist = ax.hist(dist_mat.values[tril_ind[0], tril_ind[1]], bins=50, **hist_args, label='no cuts');

# tril_ind = np.tril_indices(dist_mat.loc[cut1_df['NMAST']][cut1_df['NMAST']].shape[0])
# ax.hist(dist_mat.loc[cut1_df['NMAST']][cut1_df['NMAST']].values[tril_ind[0], tril_ind[1]],
#         bins=hist[1], **hist_args, label='q,z > 0');

# tril_ind = np.tril_indices(dist_mat.loc[cut2_df['NMAST']][cut2_df['NMAST']].shape[0])
# ax.hist(dist_mat.loc[cut1_df['NMAST']][cut2_df['NMAST']].values[tril_ind[0], tril_ind[1]],
#         bins=hist[1], **hist_args, label='q >= 0.95');

# ax.legend()
# ax.set_xlabel("Pairwise distance [pixels]")
# ax.set_ylabel("N pairs")

# %%
# check R0005193 and R0005195
star_ids = ["R0005193", "R0005195"]
for star_id in star_ids:
    print(i, point_sources_df.query("NMAST == @star_id").shape[0])
# Out:
# R0006552 27
# R0006552 27

# %%
unique_samesies = []
for i in samesies:
    if i in unique_samesies:
        pass
    else:
        unique_samesies.append(i)

# %%
unique_samesies;

# %%
for star_ids in unique_samesies:
    #print("New set\n")
    for i in star_ids:
        ndet = point_sources_df.query("NMAST == @i")['NMAST'].size
        q_avg = point_sources_df.query("NMAST == @i")[['q1','q2','q3']].mean().mean()
        q_std = point_sources_df.query("NMAST == @i")[['q1','q2','q3']].std().std()
        z_avg = point_sources_df.query("NMAST == @i")[['z1','z2','z3']].mean().mean()
        z_std = point_sources_df.query("NMAST == @i")[['z1','z2','z3']].std().std()
        print(f"{i}\t{ndet}\t{q_avg:0.2f} +/- {q_std:0.2f}\t{z_avg:0.2f} +/- {z_std:0.2f}")
    print("\n")
# Out:
# R0002784	27	1.00 +/- 0.00	458.83 +/- 1.54
#
#
# R0002787	27	1.00 +/- 0.00	179.69 +/- 1.23
# R0002789	27	1.00 +/- 0.00	179.69 +/- 1.23
#
#
# R0002816	54	1.00 +/- 0.00	257.75 +/- 1.49
# R0002815	54	1.00 +/- 0.00	257.75 +/- 1.49
#
#
# R0002831	54	1.00 +/- 0.00	1520.90 +/- 2.44
# R0002830	54	1.00 +/- 0.00	1520.90 +/- 2.44
#
#
# R0002859	54	1.00 +/- 0.00	304.85 +/- 0.79
# R0002858	54	1.00 +/- 0.00	304.85 +/- 0.79
#
#
# R0002890	27	1.00 +/- 0.00	55.54 +/- 0.14
# R0002887	27	1.00 +/- 0.00	55.54 +/- 0.14
#
#
# R0002894	27	1.00 +/- 0.00	487.18 +/- 2.73
# R0002896	27	1.00 +/- 0.00	487.18 +/- 2.73
#
#
# R0002916	27	1.00 +/- 0.00	64.85 +/- 0.25
# R0002917	27	1.00 +/- 0.00	64.85 +/- 0.25
#
#
# R0002924	27	1.00 +/- 0.00	289.38 +/- 1.52
# R0002925	27	1.00 +/- 0.00	289.38 +/- 1.52
#
#
# R0002926	27	1.00 +/- 0.00	125.77 +/- 1.37
# R0002927	27	1.00 +/- 0.00	125.77 +/- 1.37
#
#
# R0002953	54	1.00 +/- 0.00	531.99 +/- 0.66
# R0002952	54	1.00 +/- 0.00	531.99 +/- 0.66
#
#
# R0002976	54	1.00 +/- 0.00	645.61 +/- 0.82
# R0002979	54	1.00 +/- 0.00	645.61 +/- 0.82
#
#
# R0002977	54	1.00 +/- 0.00	48.96 +/- 0.12
# R0002978	54	1.00 +/- 0.00	48.96 +/- 0.12
#
#
# R0002981	54	1.00 +/- 0.00	5030.44 +/- 4.16
# R0002980	54	1.00 +/- 0.00	5030.44 +/- 4.16
#
#
# R0003003	34	1.00 +/- 0.00	4237.33 +/- 8.85
# R0003005	34	1.00 +/- 0.00	4237.33 +/- 8.85
#
#
# R0003021	54	1.00 +/- 0.00	506.13 +/- 1.02
# R0003019	54	1.00 +/- 0.00	506.13 +/- 1.02
#
#
# R0003043	54	1.00 +/- 0.00	709.61 +/- 1.60
# R0003042	54	1.00 +/- 0.00	709.61 +/- 1.60
#
#
# R0003099	54	1.00 +/- 0.00	83.20 +/- 0.76
# R0003098	54	1.00 +/- 0.00	83.20 +/- 0.76
#
#
# R0003100	54	1.00 +/- 0.00	311.00 +/- 1.39
# R0003102	54	1.00 +/- 0.00	311.00 +/- 1.39
#
#
# R0003107	54	1.00 +/- 0.00	98.02 +/- 0.16
# R0003108	54	1.00 +/- 0.00	98.02 +/- 0.16
#
#
# R0003124	54	1.00 +/- 0.00	875.11 +/- 2.02
# R0003122	54	1.00 +/- 0.00	875.11 +/- 2.02
#
#
# R0003170	54	1.00 +/- 0.00	57.92 +/- 0.46
# R0003171	54	1.00 +/- 0.00	57.92 +/- 0.46
#
#
# R0003245	45	1.00 +/- 0.00	117.29 +/- 0.35
# R0003244	45	1.00 +/- 0.00	117.29 +/- 0.35
#
#
# R0003472	27	0.99 +/- 0.00	36.69 +/- 0.21
# R0004419	36	1.00 +/- 0.00	207.74 +/- 0.87
# R0004418	36	1.00 +/- 0.00	207.74 +/- 0.87
#
#
# R0004421	27	1.00 +/- 0.00	284.64 +/- 1.27
# R0004420	27	1.00 +/- 0.00	284.64 +/- 1.27
#
#
# R0004429	27	1.00 +/- 0.00	588.70 +/- 1.09
# R0004431	27	1.00 +/- 0.00	588.70 +/- 1.09
#
#
# R0004433	54	1.00 +/- 0.00	921.38 +/- 2.44
# R0004434	54	1.00 +/- 0.00	921.38 +/- 2.44
#
#
# R0004438	54	1.00 +/- 0.00	180.69 +/- 0.24
# R0004436	54	1.00 +/- 0.00	180.69 +/- 0.24
#
#
# R0004457	27	1.00 +/- 0.00	341.15 +/- 1.57
# R0004458	27	1.00 +/- 0.00	341.15 +/- 1.57
#
#
# R0004461	27	1.00 +/- 0.00	356.22 +/- 1.98
# R0004464	27	1.00 +/- 0.00	356.22 +/- 1.98
#
#
# R0004463	48	1.00 +/- 0.00	1787.52 +/- 7.71
# R0004465	48	1.00 +/- 0.00	1787.52 +/- 7.71
#
#
# R0004512	54	1.00 +/- 0.00	837.40 +/- 1.91
# R0004511	54	1.00 +/- 0.00	837.40 +/- 1.91
#
#
# R0004522	36	1.00 +/- 0.00	154.91 +/- 0.46
# R0004521	36	1.00 +/- 0.00	154.91 +/- 0.46
#
#
# R0004548	40	0.99 +/- 0.09	265.36 +/- 20.62
# R0004546	40	0.99 +/- 0.09	265.36 +/- 20.62
#
#
# R0004556	54	0.99 +/- 0.00	30.45 +/- 0.05
# R0004555	54	0.99 +/- 0.00	30.45 +/- 0.05
#
#
# R0004568	27	1.00 +/- 0.00	203.32 +/- 1.83
# R0004567	27	1.00 +/- 0.00	203.32 +/- 1.83
#
#
# R0004591	54	1.00 +/- 0.00	8404.40 +/- 27.63
# R0004592	54	1.00 +/- 0.00	8404.40 +/- 27.63
#
#
# R0004653	27	1.00 +/- 0.00	154.11 +/- 0.46
# R0004655	27	1.00 +/- 0.00	154.11 +/- 0.46
#
#
# R0004680	27	1.00 +/- 0.00	45.54 +/- 0.34
# R0004679	27	1.00 +/- 0.00	45.54 +/- 0.34
#
#
# R0004695	27	1.00 +/- 0.00	612.24 +/- 2.54
# R0004693	27	1.00 +/- 0.00	612.24 +/- 2.54
#
#
# R0004703	52	1.00 +/- 0.00	5111.70 +/- 9.06
# R0004702	52	1.00 +/- 0.00	5111.70 +/- 9.06
#
#
# R0004741	27	1.00 +/- 0.00	451.91 +/- 1.77
# R0004742	27	1.00 +/- 0.00	451.91 +/- 1.77
#
#
# R0004745	27	0.99 +/- 0.00	58.57 +/- 0.29
# R0004746	27	0.99 +/- 0.00	58.57 +/- 0.29
#
#
# R0004756	27	1.00 +/- 0.00	297.01 +/- 2.82
# R0004755	27	1.00 +/- 0.00	297.01 +/- 2.82
#
#
# R0004758	27	0.99 +/- 0.00	36.01 +/- 0.20
# R0004757	27	0.99 +/- 0.00	36.01 +/- 0.20
#
#
# R0004767	27	1.00 +/- 0.00	364.18 +/- 2.33
# R0004766	27	1.00 +/- 0.00	364.18 +/- 2.33
#
#
# R0004941	27	0.99 +/- 0.00	36.18 +/- 0.58
# R0004942	27	0.99 +/- 0.00	36.18 +/- 0.58
#
#
# R0004967	27	1.00 +/- 0.00	801.97 +/- 2.67
# R0004965	27	1.00 +/- 0.00	801.97 +/- 2.67
#
#
# R0004970	27	1.00 +/- 0.00	135.97 +/- 0.37
# R0004971	27	1.00 +/- 0.00	135.97 +/- 0.37
#
#
# R0004978	27	1.00 +/- 0.00	2607.16 +/- 9.96
# R0004979	27	1.00 +/- 0.00	2607.16 +/- 9.96
#
#
# R0005008	27	1.00 +/- 0.00	5491.82 +/- 14.55
# R0005009	27	1.00 +/- 0.00	5491.82 +/- 14.55
#
#
# R0005040	27	1.00 +/- 0.00	1011.80 +/- 6.26
# R0005038	27	1.00 +/- 0.00	1011.80 +/- 6.26
#
#
# R0005049	27	1.00 +/- 0.00	1238.02 +/- 2.27
# R0005050	27	1.00 +/- 0.00	1238.02 +/- 2.27
#
#
# R0005055	27	1.00 +/- 0.00	45.08 +/- 0.12
# R0005054	27	1.00 +/- 0.00	45.08 +/- 0.12
#
#
# R0005062	27	1.00 +/- 0.00	371.09 +/- 0.16
# R0005060	27	1.00 +/- 0.00	371.09 +/- 0.16
#
#
# R0005077	27	1.00 +/- 0.00	1600.17 +/- 1.89
# R0005076	27	1.00 +/- 0.00	1600.17 +/- 1.89
#
#
# R0005081	27	1.00 +/- 0.00	487.04 +/- 0.56
# R0005082	27	1.00 +/- 0.00	487.04 +/- 0.56
#
#
# R0005087	27	1.00 +/- 0.00	5162.74 +/- 7.03
# R0005085	27	1.00 +/- 0.00	5162.74 +/- 7.03
#
#
# R0005137	27	1.00 +/- 0.00	2705.76 +/- 11.41
# R0005136	27	1.00 +/- 0.00	2705.76 +/- 11.41
#
#
# R0005142	27	1.00 +/- 0.00	120.10 +/- 0.82
# R0005141	27	1.00 +/- 0.00	120.10 +/- 0.82
#
#
# R0005150	27	1.00 +/- 0.00	427.95 +/- 2.84
# R0005151	27	1.00 +/- 0.00	427.95 +/- 2.84
#
#
# R0005156	27	1.00 +/- 0.00	129.32 +/- 0.97
# R0005155	27	1.00 +/- 0.00	129.32 +/- 0.97
#
#
# R0005165	27	1.00 +/- 0.00	186.07 +/- 0.69
# R0005164	27	1.00 +/- 0.00	186.07 +/- 0.69
#
#
# R0005189	27	1.00 +/- 0.00	2499.17 +/- 5.55
# R0005190	27	1.00 +/- 0.00	2499.17 +/- 5.55
#
#
# R0005195	27	1.00 +/- 0.00	26382.56 +/- 147.83
# R0005193	27	1.00 +/- 0.00	26382.56 +/- 147.83
#
#
# R0005218	27	1.00 +/- 0.00	1430.87 +/- 8.64
# R0005219	27	1.00 +/- 0.00	1430.87 +/- 8.64
#
#
# R0005224	27	1.00 +/- 0.00	153.02 +/- 0.77
# R0005223	27	1.00 +/- 0.00	153.02 +/- 0.77
#
#
# R0005228	27	1.00 +/- 0.00	1518.87 +/- 11.26
# R0005229	27	1.00 +/- 0.00	1518.87 +/- 11.26
#
#
# R0005243	27	1.00 +/- 0.00	581.74 +/- 4.18
# R0005246	27	1.00 +/- 0.00	581.74 +/- 4.18
#
#
# R0005244	27	1.00 +/- 0.00	383.18 +/- 3.35
# R0005245	27	1.00 +/- 0.00	383.18 +/- 3.35
#
#
# R0005250	27	1.00 +/- 0.00	343.53 +/- 0.61
# R0005248	27	1.00 +/- 0.00	343.53 +/- 0.61
#
#
# R0005251	23	0.98 +/- 0.12	436.67 +/- 34.44
# R0005252	23	0.98 +/- 0.12	436.67 +/- 34.44
#
#
# R0005254	27	1.00 +/- 0.00	977.21 +/- 14.31
# R0005255	27	1.00 +/- 0.00	977.21 +/- 14.31
#
#
# R0005291	27	1.00 +/- 0.00	165.52 +/- 0.19
# R0005292	27	1.00 +/- 0.00	165.52 +/- 0.19
#
#
# R0005308	27	1.00 +/- 0.00	11674.53 +/- 47.40
# R0005309	27	1.00 +/- 0.00	11674.53 +/- 47.40
#
#
# R0005317	27	1.00 +/- 0.00	1141.05 +/- 0.41
# R0005318	27	1.00 +/- 0.00	1141.05 +/- 0.41
#
#
# R0005322	27	1.00 +/- 0.00	427.67 +/- 0.64
# R0005321	27	1.00 +/- 0.00	427.67 +/- 0.64
#
#
# R0005324	27	1.00 +/- 0.00	1904.72 +/- 2.45
# R0005323	27	1.00 +/- 0.00	1904.72 +/- 2.45
#
#
# R0005325	27	1.00 +/- 0.00	440.09 +/- 0.86
# R0005327	27	1.00 +/- 0.00	440.09 +/- 0.86
#
#
# R0005390	27	1.00 +/- 0.00	292.21 +/- 0.40
# R0005391	27	1.00 +/- 0.00	292.21 +/- 0.40
#
#
# R0005394	27	1.00 +/- 0.00	575.34 +/- 1.96
# R0005392	27	1.00 +/- 0.00	575.34 +/- 1.96
#
#
# R0005396	27	1.00 +/- 0.00	2057.66 +/- 5.98
# R0005397	27	1.00 +/- 0.00	2057.66 +/- 5.98
#
#
# R0005414	27	1.00 +/- 0.00	44.13 +/- 0.27
# R0005415	27	1.00 +/- 0.00	44.13 +/- 0.27
#
#
# R0005417	24	1.00 +/- 0.00	90.44 +/- 1.25
# R0005418	24	1.00 +/- 0.00	90.44 +/- 1.25
#
#
# R0005436	27	1.00 +/- 0.00	1592.78 +/- 7.21
# R0005435	27	1.00 +/- 0.00	1592.78 +/- 7.21
#
#
# R0005442	27	1.00 +/- 0.00	833.38 +/- 2.16
# R0005443	27	1.00 +/- 0.00	833.38 +/- 2.16
#
#
# R0005465	27	1.00 +/- 0.00	654.06 +/- 0.57
# R0005464	27	1.00 +/- 0.00	654.06 +/- 0.57
#
#
# R0005499	27	1.00 +/- 0.00	95.73 +/- 0.55
# R0005498	27	1.00 +/- 0.00	95.73 +/- 0.55
#
#
# R0005507	27	1.00 +/- 0.00	83.94 +/- 0.22
# R0005509	27	1.00 +/- 0.00	83.94 +/- 0.22
#
#
# R0005512	27	1.00 +/- 0.00	51.79 +/- 0.23
# R0005513	27	1.00 +/- 0.00	51.79 +/- 0.23
#
#
# R0005520	27	1.00 +/- 0.00	181.31 +/- 0.79
# R0005521	27	1.00 +/- 0.00	181.31 +/- 0.79
#
#
# R0005524	27	1.00 +/- 0.00	1582.59 +/- 4.44
# R0006024	27	1.00 +/- 0.00	244.16 +/- 1.30
# R0006023	27	1.00 +/- 0.00	244.16 +/- 1.30
#
#
# R0006026	27	1.00 +/- 0.00	510.72 +/- 1.38
# R0006025	27	1.00 +/- 0.00	510.72 +/- 1.38
#
#
# R0006070	21	0.98 +/- 0.12	31.81 +/- 2.23
# R0006071	21	0.98 +/- 0.12	31.81 +/- 2.23
#
#
# R0006073	27	1.00 +/- 0.00	378.87 +/- 1.22
# R0006074	27	1.00 +/- 0.00	378.87 +/- 1.22
#
#
# R0006077	27	1.00 +/- 0.00	354.39 +/- 0.17
# R0006076	27	1.00 +/- 0.00	354.39 +/- 0.17
#
#
# R0006170	27	1.00 +/- 0.00	100.17 +/- 0.22
# R0006169	27	1.00 +/- 0.00	100.17 +/- 0.22
#
#
# R0006174	27	1.00 +/- 0.00	216.57 +/- 0.12
# R0006173	27	1.00 +/- 0.00	216.57 +/- 0.12
#
#
# R0006245	27	1.00 +/- 0.00	285.99 +/- 0.31
# R0006244	27	1.00 +/- 0.00	285.99 +/- 0.31
#
#
# R0006300	27	1.00 +/- 0.00	2466.25 +/- 8.26
# R0006301	27	1.00 +/- 0.00	2466.25 +/- 8.26
#
#
# R0006348	25	1.00 +/- 0.00	206.73 +/- 1.47
# R0006347	25	1.00 +/- 0.00	206.73 +/- 1.47
#
#
# R0006410	27	1.00 +/- 0.00	618.12 +/- 1.04
# R0006411	27	1.00 +/- 0.00	618.12 +/- 1.04
#
#
# R0006463	27	1.00 +/- 0.00	238.88 +/- 0.65
# R0006462	27	1.00 +/- 0.00	238.88 +/- 0.65
#
#
# R0006476	27	1.00 +/- 0.00	89.78 +/- 0.40
# R0006477	27	1.00 +/- 0.00	89.78 +/- 0.40
#
#
# R0006486	27	1.00 +/- 0.00	111.70 +/- 0.48
# R0006487	27	1.00 +/- 0.00	111.70 +/- 0.48
#
#
# R0006503	27	1.00 +/- 0.00	656.39 +/- 2.21
# R0006502	27	1.00 +/- 0.00	656.39 +/- 2.21
#
#
# R0006535	18	1.00 +/- 0.00	302.42 +/- 2.72
# R0006533	18	1.00 +/- 0.00	302.42 +/- 2.72

# %%
point_sources_df.query("master_exp_id == 'G001'").query("NMAST == 'R0006533' or NMAST == 'R0006535'").T;

# %%
dist_mat.loc['R0006533', 'R0006535']
# Out:
# 0.0

# %% [markdown]
# Wait, these are actual duplicates of each other

# %% [markdown]
# # Removing identical entries
# These entries are identical except for the actual star identifiers

# %%
cols = list(point_sources_df.columns)
for i in ['NMAST', 'ps_tile_id', 'tile_id', 'master_exp_id', 'filt_id', 'unk', 'chip_id']:
    cols.pop(cols.index(i))

point_sources_df.drop_duplicates(subset=cols, keep='first')
# Out:
#            umast     vmast    magu  utile  vtile    z0  sz0  f0  g0      u1  \
# 0        736.424    91.482 -2.0238    0.0    0.0   6.5  0.8   0   1  31.849
# 1        736.459    91.452 -1.4531    0.0    0.0   3.7  0.8   0   1  31.918
# 2        736.323    91.491 -2.5450    0.0    0.0  10.4  0.8   0   1  31.646
# 3        736.306    91.445 -2.2584    0.0    0.0   8.3  0.8   0   1  31.611
# 4        736.398    91.671 -2.5036    0.0    0.0   9.6  0.8   0   1  31.797
# ...          ...       ...     ...    ...    ...   ...  ...  ..  ..     ...
# 204678  1123.238  1594.778 -0.9718    0.0    0.0  -0.4  0.6   0   1  85.476
# 204679  1123.163  1594.772 -1.9953    0.0    0.0   5.3  0.6   0   1  85.327
# 204680  1123.230  1594.817 -1.4931    0.0    0.0   8.4  0.6   0   1  85.460
# 204681  1123.607  1594.519 -2.4661    0.0    0.0   8.8  0.7   0   1  86.214
# 204682  1123.109  1595.099 -0.0000    0.0    0.0  -0.5  0.6   0   1  85.218
#
#         ...   o3  f3  g3     NMAST  ps_tile_id  tile_id  master_exp_id  \
# 0       ...  0.0   1   1  R0000001        L005     N001           G004
# 1       ...  0.0   1   1  R0000001        L005     N002           G006
# 2       ...  0.0   1   1  R0000001        L005     N003           G007
# 3       ...  0.0   1   1  R0000001        L005     N004           G009
# 4       ...  0.0   1   1  R0000001        L005     N005           G010
# ...     ...  ...  ..  ..       ...         ...      ...            ...
# 204678  ...  0.0   1   1  R0006552        L013     N021           G043
# 204679  ...  0.0   1   1  R0006552        L013     N022           G047
# 204680  ...  0.0   1   1  R0006552        L013     N023           G048
# 204681  ...  0.0   1   1  R0006552        L013     N024           G049
# 204682  ...  0.0   1   1  R0006552        L013     N026           G053
#
#         filt_id  unk  chip_id
# 0            F1    C        1
# 1            F1    C        1
# 2            F1    C        1
# 3            F1    C        1
# 4            F1    C        1
# ...         ...  ...      ...
# 204678       F2    C        1
# 204679       F2    C        1
# 204680       F2    C        1
# 204681       F2    C        1
# 204682       F2    C        1
#
# [194653 rows x 42 columns]

# %%
point_sources_df.drop_duplicates(subset=cols, keep=False)
# Out:
#            umast     vmast    magu  utile  vtile    z0  sz0  f0  g0      u1  \
# 0        736.424    91.482 -2.0238    0.0    0.0   6.5  0.8   0   1  31.849
# 1        736.459    91.452 -1.4531    0.0    0.0   3.7  0.8   0   1  31.918
# 2        736.323    91.491 -2.5450    0.0    0.0  10.4  0.8   0   1  31.646
# 3        736.306    91.445 -2.2584    0.0    0.0   8.3  0.8   0   1  31.611
# 4        736.398    91.671 -2.5036    0.0    0.0   9.6  0.8   0   1  31.797
# ...          ...       ...     ...    ...    ...   ...  ...  ..  ..     ...
# 204678  1123.238  1594.778 -0.9718    0.0    0.0  -0.4  0.6   0   1  85.476
# 204679  1123.163  1594.772 -1.9953    0.0    0.0   5.3  0.6   0   1  85.327
# 204680  1123.230  1594.817 -1.4931    0.0    0.0   8.4  0.6   0   1  85.460
# 204681  1123.607  1594.519 -2.4661    0.0    0.0   8.8  0.7   0   1  86.214
# 204682  1123.109  1595.099 -0.0000    0.0    0.0  -0.5  0.6   0   1  85.218
#
#         ...   o3  f3  g3     NMAST  ps_tile_id  tile_id  master_exp_id  \
# 0       ...  0.0   1   1  R0000001        L005     N001           G004
# 1       ...  0.0   1   1  R0000001        L005     N002           G006
# 2       ...  0.0   1   1  R0000001        L005     N003           G007
# 3       ...  0.0   1   1  R0000001        L005     N004           G009
# 4       ...  0.0   1   1  R0000001        L005     N005           G010
# ...     ...  ...  ..  ..       ...         ...      ...            ...
# 204678  ...  0.0   1   1  R0006552        L013     N021           G043
# 204679  ...  0.0   1   1  R0006552        L013     N022           G047
# 204680  ...  0.0   1   1  R0006552        L013     N023           G048
# 204681  ...  0.0   1   1  R0006552        L013     N024           G049
# 204682  ...  0.0   1   1  R0006552        L013     N026           G053
#
#         filt_id  unk  chip_id
# 0            F1    C        1
# 1            F1    C        1
# 2            F1    C        1
# 3            F1    C        1
# 4            F1    C        1
# ...         ...  ...      ...
# 204678       F2    C        1
# 204679       F2    C        1
# 204680       F2    C        1
# 204681       F2    C        1
# 204682       F2    C        1
#
# [184623 rows x 42 columns]

# %%
point_sources_df[point_sources_df.duplicated(subset=cols, keep=False)]['NMAST'].unique().size
# Out:
# 716

# %%
cols = list(master_catalog_df.columns)
cols.pop(cols.index("NMAST"))
unique_ind = master_catalog_df.drop_duplicates(subset=cols).index

# %%
dup_ind = set.difference(set(master_catalog_df.index), set(unique_ind))

# %%
master_catalog_df.loc[dup_ind]
# Out:
#        umast0  vmast0  mmast1     NMAST    zmast1  szmast1     q1    o1  f1  \
# 4100  1410.26  975.32 -8.4633  R0004101  2428.495   58.838  0.999  1.31   9
# 5      749.93  124.75 -4.4803  R0000006    61.959    3.305  0.997  0.00   9
# 7      754.79   70.36 -8.5803  R0000008  2704.709   35.819  1.000  0.13   5
# 4113  1435.88  914.27 -7.2660  R0004114   806.117   10.678  1.000  7.20   9
# 22     834.77   43.73 -8.3215  R0000023  2131.079   17.199  1.000  0.15   9
# ...       ...     ...     ...       ...       ...      ...    ...   ...  ..
# 4031  1187.23  937.41 -6.6186  R0004032   444.038    5.796  0.999  0.00   9
# 4036  1195.24  975.72 -7.2780  R0004037   815.059   14.309  0.999  0.30   9
# 4039  1197.25  969.12 -7.6728  R0004040  1172.524   14.749  0.999  0.18   9
# 4040  1197.74  860.15 -8.1497  R0004041  1819.263   14.158  1.000  0.16   9
# 4089  1384.90  928.76 -6.7667  R0004090   508.965    4.462  1.000  1.87   9
#
#       g1    zmast2  szmast2     q2    o2  f2  g2
# 4100   9  3125.836   34.168  0.999  1.76  18  18
# 5      9    84.200    2.850  0.998  0.00  18  18
# 7      5  3227.365   47.837  1.000  0.19   9   9
# 4113   9   963.330   14.263  0.999  7.39  18  18
# 22     9  2200.292  131.793  1.000  0.12  18  18
# ...   ..       ...      ...    ...   ...  ..  ..
# 4031   9   458.005   12.369  0.999  0.01  18  18
# 4036   9   957.949   47.928  0.999  0.28  18  18
# 4039   9  1427.434   16.134  0.999  0.28  18  15
# 4040   9  1993.288   29.039  1.000  0.13  18  18
# 4089   9   806.432   14.477  0.999  2.49  18  18
#
# [358 rows x 16 columns]

# %%
6552-6194
# Out:
# 358

# %%
cols = list(master_catalog_df.columns)
cols.pop(cols.index("NMAST"))
dups = master_catalog_df[master_catalog_df.duplicated(subset=cols, keep=False)]

# %%
gb = dups.groupby(cols)

# %%
len(gb.groups)
# Out:
# 358

# %%
tmp = [list(gb.get_group(group)['NMAST'].values)
       for group, index in gb.groups.items()]
# pairs = {pair[0]: pair for pair in pairs}
# pairs = [[(pair[0], p) for p in pair] for pair in pairs]

# %%
pairs = []
# for pair in tmp:
#     for p in pair:
#         pairs[pair[0]] = p
for group, index in gb.groups.items():
    names = list(gb.get_group(group)['NMAST'].values)
    key = names[0]
    for n in names:
        pairs.append((n, key))

# %%
pairs;

# %%
# columns: 'name' contains the original name, 'main_id' is the one you'll be keeping
pairs_df = pd.DataFrame(pairs, columns=['name','main_id'])

# %%
pairs_df.head()
# Out:
#        name   main_id
# 0  R0002708  R0002708
# 1  R0002711  R0002708
# 2  R0001942  R0001942
# 3  R0001943  R0001942
# 4  R0002709  R0002709

# %%
point_sources_df.columns
# Out:
# Index(['umast', 'vmast', 'magu', 'utile', 'vtile', 'z0', 'sz0', 'f0', 'g0',
#        'u1', 'v1', 'x1', 'y1', 'xraw1', 'yraw1', 'z1', 'sz1', 'q1', 'o1', 'f1',
#        'g1', 'x0', 'y0', 'z2', 'sz2', 'q2', 'o2', 'f2', 'g2', 'z3', 'sz3',
#        'q3', 'o3', 'f3', 'g3', 'NMAST', 'ps_tile_id', 'tile_id',
#        'master_exp_id', 'filt_id', 'unk', 'chip_id'],
#       dtype='object')

# %%
point_sources_df[['NMAST', 'ps_tile_id', 'tile_id', 'master_exp_id', 'filt_id', 'unk', 'chip_id']].head()
# Out:
#       NMAST ps_tile_id tile_id master_exp_id filt_id unk  chip_id
# 0  R0000001       L005    N001          G004      F1   C        1
# 1  R0000001       L005    N002          G006      F1   C        1
# 2  R0000001       L005    N003          G007      F1   C        1
# 3  R0000001       L005    N004          G009      F1   C        1
# 4  R0000001       L005    N005          G010      F1   C        1

# %%
master_catalog_df.head()
# Out:
#    umast0  vmast0  mmast1     NMAST   zmast1  szmast1     q1    o1  f1  g1  \
# 0  736.37   91.51 -2.3045  R0000001    8.352    2.586  0.900  0.01   9   9
# 1  737.04   34.36 -3.2771  R0000002   20.458    2.260  0.899  0.00   9   9
# 2  740.65   61.26 -5.9669  R0000003  243.655    3.332  0.999  0.01   9   9
# 3  745.91   93.19 -2.9646  R0000004   15.340    1.092  0.968  0.01   9   9
# 4  749.93  124.75 -4.4803  R0000005   61.959    3.305  0.997  0.00   9   9
#
#     zmast2  szmast2     q2    o2  f2  g2
# 0   14.088    1.538  0.963  0.01   9   9
# 1    9.987    2.508  0.909  0.00  16  16
# 2  177.850    2.386  0.999  0.02   9   9
# 3   19.786    2.601  0.982  0.01   9   9
# 4   84.200    2.850  0.998  0.00  18  18

# %% [markdown]
# get a list of the remaining point sources

# %%
ps_cols = list(point_sources_df.columns)
for i in ['NMAST', 'g0','g1','g2','g3', 'ps_tile_id', 'tile_id', 'master_exp_id', 'filt_id', 'unk', 'chip_id']:
    ps_cols.pop(ps_cols.index(i))

ps_cat_nodup = point_sources_df.drop_duplicates(subset=ps_cols, keep='first')
ps_cat_dups = point_sources_df[point_sources_df.duplicated(subset=ps_cols, keep=False)]

# %%
ps_cat_nodup['NMAST'].unique().size
# Out:
# 6194

# %%
import time

# %%
import itertools

# %%
t0 = time.time()
ps_gb = point_sources_df.groupby(ps_cols)
# name_sets = []
# for k, v in ps_gb.groups.items():
#     if len(v) > 1:
#         names = point_sources_df.loc[v, 'NMAST'].values
#         name_pairs = [tuple(i) for i in list(itertools.product([names[0]], names))]
#         for n in name_pairs:
#             name_sets.append(n)
# # name_sets = set(name_sets)
# # uniqify
# name_sets = pd.DataFrame(data=sorted(list(set(name_sets))), columns=['primary_id','alias'])
# t1 = time.time()
# print(f"{(t1-t0):0.2f}")

# %%
keep_indices = [sorted(ind)[0] for ind in ps_gb.groups.values()]
np.shape(keep_indices)
# Out:
# (194629,)

# %% [markdown]
# # OK, I have it!
#
# Everything that works is wrapped up in ks2_utils.remove_duplicates(). Run it and write the new catalogs to file.

# %%
reload(ks2_utils)
# Out:
# <module 'utils.ks2_utils' from '/user/jaguilar/tr14/tr14/utils/ks2_utils.py'>

# %%
point_sources_df = ks2_utils.get_point_source_catalog(raw=True)
master_catalog_df = ks2_utils.get_master_catalog(raw=True)
ps_cat, mast_cat = ks2_utils.remove_duplicates(point_sources_df, master_catalog_df)
# Out:
# /Users/jaguilar/miniconda3/envs/astro37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (20,28,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
ps_dups = ps_cat[ps_cat.duplicated(subset=ps_cols, keep=False)]

# %%
ps_dups.empty
# Out:
# True

# %%
dups = mast_cat[mast_cat.duplicated(subset=mast_cols, keep=False)]['NMAST']

# %%
dups.empty
# Out:
# True

# %%
ks2_utils.ks2_files
# Out:
# [PosixPath('/user/jaguilar/tr14/data/ks2/LOGR.XYVIQ1'),
#  PosixPath('/user/jaguilar/tr14/data/ks2/LOGR.FIND_NIMFO'),
#  PosixPath('/user/jaguilar/tr14/data/ks2/INPUT.KS2')]

# %%
csv_args = {'index':False, "na_rep":None, "header":True}

# %%
ps_cat.to_csv(ks2_utils.ks2_files[1].as_posix() + '-nodup.csv', **csv_args)

# %%
mast_cat.to_csv(ks2_utils.ks2_files[0].as_posix() + '-nodup.csv', **csv_args)

# %%
pd.read_csv(ks2_utils.ks2_files[0].as_posix() + '-nodup.csv', sep=',').head()
# Out:
#    umast0  vmast0  mmast1     NMAST   zmast1  szmast1     q1    o1  f1  g1  \
# 0  736.37   91.51 -2.3045  R0000001    8.352    2.586  0.900  0.01   9   9
# 1  737.04   34.36 -3.2771  R0000002   20.458    2.260  0.899  0.00   9   9
# 2  740.65   61.26 -5.9669  R0000003  243.655    3.332  0.999  0.01   9   9
# 3  745.91   93.19 -2.9646  R0000004   15.340    1.092  0.968  0.01   9   9
# 4  749.93  124.75 -4.4803  R0000005   61.959    3.305  0.997  0.00   9   9
#
#     zmast2  szmast2     q2    o2  f2  g2
# 0   14.088    1.538  0.963  0.01   9   9
# 1    9.987    2.508  0.909  0.00  16  16
# 2  177.850    2.386  0.999  0.02   9   9
# 3   19.786    2.601  0.982  0.01   9   9
# 4   84.200    2.850  0.998  0.00  18  18

# %%
mast_cat[mast_cat.duplicated(subset=mast_cols, keep=False)].empty
# Out:
# True

# %%
ps_cat[ps_cat.duplicated(subset=cols, keep=False)].empty
# Out:
# True
